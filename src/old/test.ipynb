# %%
import numpy as np

# %%
sigma_max = 1.0
sigma_min = 1e-3
T1_T = 100

noise_schedule1 = np.geomspace(sigma_max, sigma_min, T1_T)

# %%
print(noise_schedule1)
# Out:
# [1.         0.93260335 0.869749   0.81113083 0.75646333 0.70548023
#  0.65793322 0.61359073 0.57223677 0.53366992 0.49770236 0.46415888
#  0.43287613 0.40370173 0.37649358 0.35111917 0.32745492 0.30538555
#  0.28480359 0.26560878 0.24770764 0.23101297 0.21544347 0.2009233
#  0.18738174 0.17475284 0.16297508 0.15199111 0.14174742 0.13219411
#  0.12328467 0.1149757  0.10722672 0.1        0.09326033 0.0869749
#  0.08111308 0.07564633 0.07054802 0.06579332 0.06135907 0.05722368
#  0.05336699 0.04977024 0.04641589 0.04328761 0.04037017 0.03764936
#  0.03511192 0.03274549 0.03053856 0.02848036 0.02656088 0.02477076
#  0.0231013  0.02154435 0.02009233 0.01873817 0.01747528 0.01629751
#  0.01519911 0.01417474 0.01321941 0.01232847 0.01149757 0.01072267
#  0.01       0.00932603 0.00869749 0.00811131 0.00756463 0.0070548
#  0.00657933 0.00613591 0.00572237 0.0053367  0.00497702 0.00464159
#  0.00432876 0.00403702 0.00376494 0.00351119 0.00327455 0.00305386
# ...

# %%
print(np.linspace(0.0, 1.0, 10)[::-1])
# Out:
# [1.         0.88888889 0.77777778 0.66666667 0.55555556 0.44444444
#  0.33333333 0.22222222 0.11111111 0.        ]

# %%
import torch
torch.linspace(1.0, 0.0, 100)
# Out:
# tensor([1.0000, 0.9899, 0.9798, 0.9697, 0.9596, 0.9495, 0.9394, 0.9293, 0.9192,
#         0.9091, 0.8990, 0.8889, 0.8788, 0.8687, 0.8586, 0.8485, 0.8384, 0.8283,
#         0.8182, 0.8081, 0.7980, 0.7879, 0.7778, 0.7677, 0.7576, 0.7475, 0.7374,
#         0.7273, 0.7172, 0.7071, 0.6970, 0.6869, 0.6768, 0.6667, 0.6566, 0.6465,
#         0.6364, 0.6263, 0.6162, 0.6061, 0.5960, 0.5859, 0.5758, 0.5657, 0.5556,
#         0.5455, 0.5354, 0.5253, 0.5152, 0.5051, 0.4949, 0.4848, 0.4747, 0.4646,
#         0.4545, 0.4444, 0.4343, 0.4242, 0.4141, 0.4040, 0.3939, 0.3838, 0.3737,
#         0.3636, 0.3535, 0.3434, 0.3333, 0.3232, 0.3131, 0.3030, 0.2929, 0.2828,
#         0.2727, 0.2626, 0.2525, 0.2424, 0.2323, 0.2222, 0.2121, 0.2020, 0.1919,
#         0.1818, 0.1717, 0.1616, 0.1515, 0.1414, 0.1313, 0.1212, 0.1111, 0.1010,
#         0.0909, 0.0808, 0.0707, 0.0606, 0.0505, 0.0404, 0.0303, 0.0202, 0.0101,
#         0.0000])
